# %%
# !nvidia-smi
# Out:
# Mon Apr  6 07:46:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Clone threestudio repo

# %%
# !git clone https://github.com/threestudio-project/threestudio.git
# Out:
# fatal: destination path 'threestudio' already exists and is not an empty directory.

# %%
# %cd threestudio
# Out:
# /content/threestudio

# %% [markdown]
# Install dependencies

# %%
# !pip install ninja
# !pip install lightning==2.0.0 omegaconf==2.3.0 jaxtyping typeguard diffusers transformers accelerate opencv-python tensorboard matplotlib imageio imageio[ffmpeg] trimesh bitsandbytes sentencepiece safetensors huggingface_hub libigl xatlas networkx pysdf PyMCubes wandb torchmetrics controlnet_aux
# !pip install einops kornia taming-transformers-rom1504 git+https://github.com/openai/CLIP.git # zero123
# !pip install open3d plotly # mesh visualization
# Out:
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: lightning==2.0.0 in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.12/dist-packages (2.3.0)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (0.3.9)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (4.5.1)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (0.37.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.3)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.12/dist-packages (4.11.5)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: libigl in /usr/local/lib/python3.12/dist-packages (2.6.2)
# Requirement already satisfied: xatlas in /usr/local/lib/python3.12/dist-packages (0.0.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Requirement already satisfied: pysdf in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: PyMCubes in /usr/local/lib/python3.12/dist-packages (0.1.6)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: controlnet_aux in /usr/local/lib/python3.12/dist-packages (0.0.10)
# Requirement already satisfied: Jinja2<5.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (3.1.6)
# Requirement already satisfied: PyYAML<8.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (6.0.3)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (1.4.0)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (4.13.5)
# Requirement already satisfied: click<10.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (8.3.1)
# Requirement already satisfied: croniter<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (1.3.15)
# Requirement already satisfied: dateutils<2.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.6.12)
# Requirement already satisfied: deepdiff<8.0,>=5.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (7.0.1)
# Requirement already satisfied: fastapi<0.89.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.88.0)
# Requirement already satisfied: fsspec<2024.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2023.12.2)
# Requirement already satisfied: inquirer<5.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (3.4.1)
# Requirement already satisfied: lightning-cloud>=0.5.31 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.6.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.15.3)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (24.2)
# Requirement already satisfied: psutil<7.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (5.9.5)
# Requirement already satisfied: pydantic<3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (1.10.26)
# Requirement already satisfied: requests<4.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2.32.4)
# Requirement already satisfied: rich<15.0,>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (13.9.4)
# Requirement already satisfied: starlette<2.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.22.0)
# Requirement already satisfied: starsessions<2.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (1.3.0)
# Requirement already satisfied: torch<4.0,>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2.10.0+cu128)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (4.67.3)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (5.7.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (4.15.0)
# Requirement already satisfied: urllib3<3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2.5.0)
# Requirement already satisfied: uvicorn<2.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (0.42.0)
# Requirement already satisfied: websocket-client<3.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (1.9.0)
# Requirement already satisfied: websockets<12.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (11.0.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning==2.0.0) (2.6.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf==2.3.0) (4.9.3)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping) (0.1.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers) (11.3.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (5.29.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]) (0.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from libigl) (1.16.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.9.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.57.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from controlnet_aux) (4.13.0.92)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from controlnet_aux) (0.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from controlnet_aux) (0.25.0+cu128)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from controlnet_aux) (1.0.26)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from controlnet_aux) (0.25.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow<3.0,>=1.2.0->lightning==2.0.0) (2025.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<6.0,>=4.8.0->lightning==2.0.0) (2.8.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from dateutils<2.0->lightning==2.0.0) (2025.2)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from deepdiff<8.0,>=5.7.0->lightning==2.0.0) (4.1.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from starlette<2.0->lightning==2.0.0) (4.13.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (3.13.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: blessed>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.0) (1.38.0)
# Requirement already satisfied: editor>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.0) (1.7.0)
# Requirement already satisfied: readchar>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.0) (4.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2<5.0->lightning==2.0.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<4.0->lightning==2.0.0) (3.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=12.3.0->lightning==2.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=12.3.0->lightning==2.0.0) (2.20.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from starsessions<2.0,>=1.2.1->lightning==2.0.0) (2.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (1.14.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=1.11.0->lightning==2.0.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<4.0,>=1.11.0->lightning==2.0.0) (1.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers) (3.23.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->controlnet_aux) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->controlnet_aux) (0.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning==2.0.0) (1.23.0)
# Requirement already satisfied: wcwidth>=0.6 in /usr/local/lib/python3.12/dist-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning==2.0.0) (0.6.0)
# Requirement already satisfied: runs in /usr/local/lib/python3.12/dist-packages (from editor>=1.6.0->inquirer<5.0,>=2.10.0->lightning==2.0.0) (1.3.0)
# Requirement already satisfied: xmod in /usr/local/lib/python3.12/dist-packages (from editor>=1.6.0->inquirer<5.0,>=2.10.0->lightning==2.0.0) (1.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0,>=12.3.0->lightning==2.0.0) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<4.0,>=1.11.0->lightning==2.0.0) (1.3.0)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-fm8ilb7x
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-fm8ilb7x
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: taming-transformers-rom1504 in /usr/local/lib/python3.12/dist-packages (0.0.6)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from taming-transformers-rom1504) (0.25.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from taming-transformers-rom1504) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from taming-transformers-rom1504) (4.67.3)
# Requirement already satisfied: omegaconf>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from taming-transformers-rom1504) (2.3.0)
# Requirement already satisfied: pytorch-lightning>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from taming-transformers-rom1504) (2.6.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2025.11.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0.0->taming-transformers-rom1504) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0.0->taming-transformers-rom1504) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (2023.12.2)
# Requirement already satisfied: torchmetrics>0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers-rom1504) (1.9.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers-rom1504) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers-rom1504) (0.15.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->kornia) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->kornia) (1.5.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->clip==1.0) (0.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->taming-transformers-rom1504) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (2.32.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (3.13.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning>=1.0.8->taming-transformers-rom1504) (2026.2.25)
# Collecting open3d
#   Using cached open3d-0.19.0-cp312-cp312-manylinux_2_31_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (2.0.2)
# Collecting dash>=2.6.0 (from open3d)
#   Using cached dash-4.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: werkzeug>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.1.7)
# Requirement already satisfied: flask>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.1.3)
# Requirement already satisfied: nbformat>=5.7.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Using cached configargparse-1.7.5-py3-none-any.whl.metadata (23 kB)
# Collecting ipywidgets>=8.0.4 (from open3d)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting addict (from open3d)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (11.3.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.12/dist-packages (from open3d) (3.10.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.12/dist-packages (from open3d) (2.2.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from open3d) (6.0.3)
# Requirement already satisfied: scikit-learn>=0.21 in /usr/local/lib/python3.12/dist-packages (from open3d) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from open3d) (4.67.3)
# Collecting pyquaternion (from open3d)
#   Using cached pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (24.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (2.32.4)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Using cached retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash>=2.6.0->open3d) (75.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->open3d) (3.0.3)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.4->open3d)
#   Using cached comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8.0.4->open3d)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.0.4->open3d) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->open3d) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7.0->open3d) (5.9.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->open3d) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->open3d) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21->open3d) (3.6.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.6.0->open3d) (2026.2.25)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.0)
# Downloading open3d-0.19.0-cp312-cp312-manylinux_2_31_x86_64.whl (447.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 4.4 MB/s eta 0:00:00
# Downloading dash-4.1.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 132.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 16.0 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading configargparse-1.7.5-py3-none-any.whl (27 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 97.7 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.5 MB/s eta 0:00:00
# Installing collected packages: addict, widgetsnbextension, retrying, pyquaternion, jedi, configargparse, comm, ipywidgets, dash, open3d
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed addict-2.4.0 comm-0.2.3 configargparse-1.7.5 dash-4.1.0 ipywidgets-8.1.8 jedi-0.19.2 open3d-0.19.0 pyquaternion-0.9.9 retrying-1.4.2 widgetsnbextension-4.0.15

# %% [markdown]
# And build some dependencies manually. This may take a while.

# %%
# !pip install git+https://github.com/ashawkey/envlight.git
# Out:
# Collecting git+https://github.com/ashawkey/envlight.git
#   Cloning https://github.com/ashawkey/envlight.git to /tmp/pip-req-build-2tt58xjh
#   Running command git clone --filter=blob:none --quiet https://github.com/ashawkey/envlight.git /tmp/pip-req-build-2tt58xjh
#   Resolved https://github.com/ashawkey/envlight.git to commit 05b5851e854429d72ecaf5b206ed64ce55fae677
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from envlight==0.1.0) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from envlight==0.1.0) (1.16.3)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from envlight==0.1.0) (1.13.0)
# Requirement already satisfied: imageio>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from envlight==0.1.0) (2.37.3)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.28.0->envlight==0.1.0) (11.3.0)
# Building wheels for collected packages: envlight
#   Building wheel for envlight (setup.py) ... done
#   Created wheel for envlight: filename=envlight-0.1.0-py3-none-any.whl size=40358 sha256=f16225defe314691f08f82bc935abdd3b153aec9a4a8bcdac0efa416f1f86843
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4k1a08zo/wheels/23/e2/45/be31bcb9c082ea45453f4dee12d7c16d84ae0630a4f889f632
# Successfully built envlight
# Installing collected packages: envlight
# Successfully installed envlight-0.1.0

# %%
# !pip install git+https://github.com/KAIR-BAIR/nerfacc.git@v0.5.2
# Out:
# Collecting git+https://github.com/KAIR-BAIR/nerfacc.git@v0.5.2
#   Cloning https://github.com/KAIR-BAIR/nerfacc.git (to revision v0.5.2) to /tmp/pip-req-build-kbdizvzt
#   Running command git clone --filter=blob:none --quiet https://github.com/KAIR-BAIR/nerfacc.git /tmp/pip-req-build-kbdizvzt
#   Running command git checkout -q d84cdf3afd7dcfc42150e0f0506db58a5ce62812
#   Resolved https://github.com/KAIR-BAIR/nerfacc.git to commit d84cdf3afd7dcfc42150e0f0506db58a5ce62812
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.12/dist-packages (from nerfacc==0.5.2) (13.9.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from nerfacc==0.5.2) (2.10.0+cu128)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->nerfacc==0.5.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->nerfacc==0.5.2) (2.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (2023.12.2)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->nerfacc==0.5.2) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->nerfacc==0.5.2) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12->nerfacc==0.5.2) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->nerfacc==0.5.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->nerfacc==0.5.2) (3.0.3)
# Building wheels for collected packages: nerfacc
#   Building wheel for nerfacc (setup.py) ... done
#   Created wheel for nerfacc: filename=nerfacc-0.5.2-cp312-cp312-linux_x86_64.whl size=1116187 sha256=5174844783af6f9a8ae93fb9efe1b6f596993f7a6ac12b8561c3888956acf7e7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5f85owbc/wheels/38/0f/1b/f2701c479c7a8722c080f9161af7dc6250949898629a904f8a
# Successfully built nerfacc
# Installing collected packages: nerfacc
# Successfully installed nerfacc-0.5.2

# %%
# !pip install git+https://github.com/NVlabs/nvdiffrast.git --no-build-isolation
# Out:
# Collecting git+https://github.com/NVlabs/nvdiffrast.git
#   Cloning https://github.com/NVlabs/nvdiffrast.git to /tmp/pip-req-build-3oyv7vk2
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast.git /tmp/pip-req-build-3oyv7vk2
#   Resolved https://github.com/NVlabs/nvdiffrast.git to commit 253ac4fcea7de5f396371124af597e6cc957bfae
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nvdiffrast==0.4.0) (2.0.2)
# Building wheels for collected packages: nvdiffrast
#   Building wheel for nvdiffrast (pyproject.toml) ... done
#   Created wheel for nvdiffrast: filename=nvdiffrast-0.4.0-cp312-cp312-linux_x86_64.whl size=16899801 sha256=73df7db627afd9ceec56c722bbacb4d0d523dc9907c50763ec0e24cffcf99452
#   Stored in directory: /tmp/pip-ephem-wheel-cache-stej14uy/wheels/d1/82/ea/91b5b9219953f7784a69f9e8d2dacad80beb8a99a5e46af62e
# Successfully built nvdiffrast
# Installing collected packages: nvdiffrast
# Successfully installed nvdiffrast-0.4.0

# %%
# !git clone https://github.com/NVlabs/tiny-cuda-nn/
# Out:
# Cloning into 'tiny-cuda-nn'...
# remote: Enumerating objects: 4486, done.
# remote: Counting objects: 100% (1646/1646), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 4486 (delta 1478), reused 1380 (delta 1379), pack-reused 2840 (from 3)
# Receiving objects: 100% (4486/4486), 19.90 MiB | 27.02 MiB/s, done.
# Resolving deltas: 100% (2851/2851), done.

# %%
# %cd ../tiny-cuda-nn/bindings/torch
# Out:
# /content/threestudio/tiny-cuda-nn/bindings/torch

# %%
# !python setup.py install
# Out:
# /content/threestudio/tiny-cuda-nn/bindings/torch/setup.py:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import parse_version
# Building PyTorch extension for tiny-cuda-nn version 2.0
# Obtained compute capability 75 from PyTorch
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Detected CUDA version 12.8
# Targeting C++ standard 17
# Auto-detecting TCNN_HALF_PRECISION: ON (Arch: 75)
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing tinycudann.egg-info/PKG-INFO
# writing dependency_links to tinycudann.egg-info/dependency_links.txt
# writing top-level names to tinycudann.egg-info/top_level.txt
# reading manifest file 'tinycudann.egg-info/SOURCES.txt'
# writing manifest file 'tinycudann.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying tinycudann/modules.py -> build/lib.linux-x86_64-cpython-312/tinycudann
# copying tinycudann/__init__.py -> build/lib.linux-x86_64-cpython-312/tinycudann
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tinycudann.rtc.include' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tinycudann.rtc.include' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tinycudann.rtc.include' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tinycudann.rtc.include' to be distributed and are
#         already explicitly excluding 'tinycudann.rtc.include' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'tinycudann.rtc.include.pcg32' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'tinycudann.rtc.include.pcg32' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'tinycudann.rtc.include.pcg32' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'tinycudann.rtc.include.pcg32' to be distributed and are
#         already explicitly excluding 'tinycudann.rtc.include.pcg32' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# copying tinycudann/bindings.cpp -> build/lib.linux-x86_64-cpython-312/tinycudann
# copying tinycudann/rtc/include/cuda_fp16.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/cuda_fp16.hpp -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_functions.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_functions.hpp -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_types.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/pcg32/LICENSE.txt -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32
# copying tinycudann/rtc/include/pcg32/pcg32.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32
# copying tinycudann/rtc/include/tiny-cuda-nn/common.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/common_device.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/common_host.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/config.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cpp_api.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cuda_graph.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cutlass_matmul.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/encoding.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_matrix.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_memory.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_memory_json.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/loss.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/matrix_layout.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/ministd.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/mma.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/multi_stream.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/network.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/network_with_input_encoding.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/object.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/optimizer.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/random.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/reduce_sum.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/rtc_kernel.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/trainer.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/vec.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/vec_json.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/vec_pybind11.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/cuda_fp16.hpp -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_functions.hpp -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/cuda_fp16.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_types.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/vector_functions.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include
# copying tinycudann/rtc/include/tiny-cuda-nn/vec.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/vec_pybind11.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_memory.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/matrix_layout.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_memory_json.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/mma.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cutlass_matmul.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/ministd.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/common.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/object.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/network_with_input_encoding.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/multi_stream.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/common_device.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/loss.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/trainer.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/encoding.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/optimizer.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/network.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/config.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/common_host.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/reduce_sum.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/gpu_matrix.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/random.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cuda_graph.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/vec_json.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/rtc_kernel.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/tiny-cuda-nn/cpp_api.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn
# copying tinycudann/rtc/include/pcg32/pcg32.h -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32
# copying tinycudann/rtc/include/pcg32/LICENSE.txt -> build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32
# running build_ext
# W0406 08:12:42.489000 16324 torch/utils/cpp_extension.py:535] There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.8
# building 'tinycudann_bindings._75_C' extension
# ninja: no work to do.
# x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../dependencies/fmt/src/format.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../dependencies/fmt/src/os.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/common_host.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/cpp_api.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/cutlass_mlp.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/encoding.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/fully_fused_mlp.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/network.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/object.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/../../src/rtc_kernel.o /content/threestudio/tiny-cuda-nn/bindings/torch/build/temp.linux-x86_64-cpython-312/tinycudann/bindings.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lcuda -lnvrtc -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/tinycudann_bindings/_75_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/tinycudann_bindings
# copying build/lib.linux-x86_64-cpython-312/tinycudann_bindings/_75_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/tinycudann_bindings
# creating build/bdist.linux-x86_64/egg/tinycudann
# copying build/lib.linux-x86_64-cpython-312/tinycudann/modules.py -> build/bdist.linux-x86_64/egg/tinycudann
# copying build/lib.linux-x86_64-cpython-312/tinycudann/bindings.cpp -> build/bdist.linux-x86_64/egg/tinycudann
# copying build/lib.linux-x86_64-cpython-312/tinycudann/__init__.py -> build/bdist.linux-x86_64/egg/tinycudann
# creating build/bdist.linux-x86_64/egg/tinycudann/rtc
# creating build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/cuda_fp16.hpp -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/vector_functions.hpp -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/cuda_fp16.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/vector_types.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# creating build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/vec.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/vec_pybind11.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/gpu_memory.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/matrix_layout.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/gpu_memory_json.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/mma.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/cutlass_matmul.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/ministd.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/common.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/object.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/network_with_input_encoding.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/multi_stream.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/common_device.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/loss.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/trainer.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/encoding.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/optimizer.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/network.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/config.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/common_host.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/reduce_sum.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/gpu_matrix.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/random.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/cuda_graph.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/vec_json.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/rtc_kernel.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/tiny-cuda-nn/cpp_api.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/tiny-cuda-nn
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/vector_functions.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include
# creating build/bdist.linux-x86_64/egg/tinycudann/rtc/include/pcg32
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32/pcg32.h -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/pcg32
# copying build/lib.linux-x86_64-cpython-312/tinycudann/rtc/include/pcg32/LICENSE.txt -> build/bdist.linux-x86_64/egg/tinycudann/rtc/include/pcg32
# byte-compiling build/bdist.linux-x86_64/egg/tinycudann/modules.py to modules.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tinycudann/__init__.py to __init__.cpython-312.pyc
# creating stub loader for tinycudann_bindings/_75_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/tinycudann_bindings/_75_C.py to _75_C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying tinycudann.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tinycudann.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tinycudann.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tinycudann.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tinycudann.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# creating dist
# creating 'dist/tinycudann-2.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing tinycudann-2.0-py3.12-linux-x86_64.egg
# creating /usr/local/lib/python3.12/dist-packages/tinycudann-2.0-py3.12-linux-x86_64.egg
# Extracting tinycudann-2.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding tinycudann 2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/tinycudann-2.0-py3.12-linux-x86_64.egg
# Processing dependencies for tinycudann==2.0
# Finished processing dependencies for tinycudann==2.0

# %% [markdown]
# Login to HuggingFace

# %%
from huggingface_hub import interpreter_login

interpreter_login()
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
# Enter your token (input will not be visible): ··········
# Add token as git credential? [y/N]: n

# %% [markdown]
# Now create your own 3D model from text prompts
#
# Here we use the DreamFusion model with DeepFloyd-IF guidance. You may try other models by using different running commands given [here](https://github.com/threestudio-project/threestudio#supported-models).

# %%
prompt = "a zoomed out DSLR photo of a baby bunny sitting on top of a stack of pancakes"

# %%
# %cd ../../..
# Out:
# /content/threestudio

# %%
# !python launch.py --config configs/dreamfusion-if.yaml --train --gpu 0 system.prompt_processor.prompt="$prompt" trainer.max_steps=10000 system.prompt_processor.spawn=false
# Out:
# Traceback (most recent call last):
#   File "/content/threestudio/launch.py", line 301, in <module>
#     main(args, extras)
#   File "/content/threestudio/launch.py", line 135, in main
#     import threestudio
#   File "/content/threestudio/threestudio/__init__.py", line 55, in <module>
#     from . import data, models, systems
#   File "/content/threestudio/threestudio/data/__init__.py", line 1, in <module>
#     from . import co3d, image, multiview, uncond, uncond_eff
#   File "/content/threestudio/threestudio/data/co3d.py", line 17, in <module>
#     from threestudio.data.uncond import (
#   File "/content/threestudio/threestudio/data/uncond.py", line 17, in <module>
#     from threestudio.utils.ops import (
#   File "/content/threestudio/threestudio/utils/ops.py", line 8, in <module>
#     from igl import fast_winding_number, point_mesh_squared_distance, read_obj
# ImportError: cannot import name 'read_obj' from 'igl' (/usr/local/lib/python3.12/dist-packages/igl/__init__.py). Did you mean: 'readOBJ'?

# %% [markdown]
# Display the rendered video

# %%
from IPython.display import HTML
from base64 import b64encode
def display_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=1000 controls>
    <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

# %%
# you will see the path to the saving directory at the end of the training logs
# replace save_dir below with that path
save_dir = 'path/to/save/dir'

import os
import glob
video_path = glob.glob(os.path.join(save_dir, "*-test.mp4"))[0]
display_video(video_path)

# %% [markdown]
# Extract the object mesh.
#
# Here we use an empirical threshold value. You can also first try `system.geometry.isosurface_threshold=auto` and visualize it. Then you can manually adjust the threshold according to the automatically determined value shown in the logs. Increase it if there are too many floaters and decrease it if the geometry is incomplete.
#
#
# The extraction process takes around 2 mins on T4.

# %%
# !python launch.py --config $save_dir/../configs/parsed.yaml --export --gpu 0 resume=$save_dir/../ckpts/last.ckpt system.exporter_type=mesh-exporter system.exporter.context_type=cuda system.geometry.isosurface_threshold=15.0

# %% [markdown]
# Visualize the mesh. Or you can directly download the export assets and use them locally.

# %%
import numpy as np
import open3d as o3d
import plotly.graph_objects as go
import glob

mesh_path = glob.glob(os.path.join(save_dir, "*-export/model.obj"))[0]
mesh = o3d.io.read_triangle_mesh(mesh_path)
if not mesh.has_vertex_normals():
  mesh.compute_vertex_normals()
if not mesh.has_triangle_normals():
  mesh.compute_triangle_normals()

triangles = np.asarray(mesh.triangles)
vertices = np.asarray(mesh.vertices)
colors = None
if mesh.has_triangle_normals():
  colors = (0.5, 0.5, 0.5) + np.asarray(mesh.triangle_normals) * 0.5
  colors = tuple(map(tuple, colors))
else:
  colors = (1.0, 0.0, 0.0)
fig = go.Figure(
  data=[
    go.Mesh3d(
      x=vertices[:,0],
      y=vertices[:,1],
      z=vertices[:,2],
      i=triangles[:,0],
      j=triangles[:,1],
      k=triangles[:,2],
      facecolor=colors,
      opacity=0.50)
  ],
  layout=dict(
    scene=dict(
      xaxis=dict(visible=False),
      yaxis=dict(visible=False),
      zaxis=dict(visible=False)
    )
  )
)
fig.show()
